# %% [markdown]
# # **Multi-Level Prompting Experiments for AI Resume Screening**
#
# ## **Overview**
# This notebook explores **multi-level automation in AI resume screening** using **Meta-Prompting** and **Multi-Step Iterative Evaluation**. The objective is to enhance **fairness, accuracy, and structured decision-making** in AI-driven hiring.
#
# ## **Experimental Setup**
# The notebook tests **two key multi-level prompt engineering techniques**:
# 1. **Meta-Prompting (Level-1 Automation)** – AI **generates an optimized prompt** before performing resume evaluation.
# 2. **Multi-Step Iterative Resume Evaluation (Level-2 Automation)** – AI **performs multiple evaluation cycles**, refining hiring decisions.
#
# ### **Key Features of This Experiment**
# - **Automated prompt generation**: Meta-Prompting ensures AI **receives structured guidance** before analyzing resumes.
# - **Iterative resume evaluation**: AI **self-refines decisions** using gap analysis and structured scoring.
# - **Optimized for performance**: Tests **three models** (Mistral, Llama3, Phi3) and **multiple parameter variations**.
#
# ## **Optimized Parameters**
# To ensure **efficiency and reliability**, we use:
# - **Temperature**: `{0.5, 1.0}` – Testing **low and high randomness**.
# - **Context Size**: `1024` – Optimized for **processing detailed resumes**.
# - **Output Length**: `300` tokens – Ensures AI **generates structured recommendations**.
#
# ## **Expected Insights**
# - **How does AI-generated prompt quality impact hiring decisions?**
# - **Can multi-step evaluations improve accuracy over a single-step analysis?**
# - **Which configurations balance efficiency and hiring decision accuracy?**
#
# **Next Steps:** Analyze test results to identify **optimal AI resume screening strategies**.

# %%
import time
import pandas as pd
from _pipeline import create_payload, model_req

# Define models to test (covering different architectures)
models_to_test = ["mistral", "llama3", "phi3"]

# Parameter variations
temperature_values = [0.5, 1.0]  # Test low and high randomness
context_sizes = [1024]  # Single, optimal context size
num_predict_values = [300]  # Single, optimal output length

# **Level-1 Automation: Meta-Prompting for Resume Screening**
meta_prompt = """
    You are an AI prompt engineer. Before performing resume screening, generate the **best possible prompt** 
    for an AI system to analyze and evaluate a candidate's resume based on a given job description.

    **Example Prompt Format:**  
    "Analyze the following job description and resume. Extract key job requirements, candidate qualifications, 
    compare them, and provide a structured match score along with hiring recommendations."

    Now, generate a high-quality prompt for resume screening and evaluation for: 
    **{job_title}**
"""

# **Level-2 Automation: Multi-Step Iterative Resume Evaluation**
multi_step_prompt = """
    You are an AI hiring assistant performing **iterative resume screening**. 

    **Step 1: Initial Candidate Evaluation**
    - Extract key job requirements.
    - Extract candidate qualifications.
    - Identify skill matches and gaps.

    **Step 2: Self-Reflection & Gap Analysis**
    - Identify missing or vague areas.
    - Determine if further clarifications are needed (e.g., missing certifications, unclear experience level).

    **Step 3: Resume Refinement & Decision Making**
    - Improve initial analysis by filling gaps.
    - Optimize scoring for accuracy and fairness.
    - Provide a structured match score (0-100%) and hiring recommendation.

    **Job Description:** {job_description}
    **Candidate Resume:** {resume_text}
"""

# Define test cases
test_cases = [
    {
        "name": "Meta-Prompting - AI Generates Resume Evaluation Prompt",
        "prompt": meta_prompt.format(job_title="Senior Data Scientist - AI & Machine Learning"),
    },
    {
        "name": "Multi-Step Iterative Resume Evaluation",
        "prompt": multi_step_prompt.format(
            job_description="""
                We are hiring a Senior Data Scientist with expertise in AI, Machine Learning, and Python. 
                The candidate must have at least 5 years of experience and strong statistical modeling skills. 
                Experience with cloud platforms (AWS, GCP) and NLP is a plus.
            """,
            resume_text="""
                John Doe is a Data Scientist with 6 years of experience. Skilled in Python, Machine Learning, and AI. 
                He has worked on predictive modeling, NLP applications, and statistical analysis. 
                Familiar with AWS, but lacks experience with GCP.
            """
        ),
    }
]

# Function to run test cases across multiple models & parameter variations
def run_tests(test_cases, models, temperatures, context_sizes, num_predict_values):
    results = []

    for test in test_cases:
        for model in models:
            for temp in temperatures:
                for ctx_size in context_sizes:
                    for num_predict in num_predict_values:
                        print(f"\n🚀 Running test: {test['name']} | Model: {model} | Temp: {temp} | Context: {ctx_size} | Predict: {num_predict}...\n")

                        # Create payload
                        payload = create_payload(
                            target="ollama",
                            model=model,
                            prompt=test["prompt"],
                            temperature=temp,
                            num_ctx=ctx_size,
                            num_predict=num_predict
                        )

                        # Measure execution time
                        start_time = time.time()
                        time_taken, response = model_req(payload=payload)
                        end_time = time.time()

                        # Store results
                        results.append({
                            "Test Case": test["name"],
                            "Model": model,
                            "Temperature": temp,
                            "Context Size": ctx_size,
                            "Num Predict": num_predict,
                            "Time Taken (s)": round(end_time - start_time, 3),
                            "Response Sample": response
                        })

                        # Print result summary
                        print(f"\n✅ **Test Completed: {test['name']} | Model: {model}**")
                        print(f"🕒 **Time Taken:** {round(end_time - start_time, 3)} seconds")
                        print(f"📌 **Response:** {response}\n")  # Print full response

    return results

# Run all test cases
test_results = run_tests(test_cases, models_to_test, temperature_values, context_sizes, num_predict_values)
test_results
# Out:
# 🚀 Running test: Meta-Prompting - AI Generates Resume Evaluation Prompt | Model: mistral | Temp: 0.5 | Context: 1024 | Predict: 300...
#
# {'model': 'mistral', 'prompt': '\n    You are an AI prompt engineer. Before performing resume screening, generate the **best possible prompt** \n    for an AI system to analyze and evaluate a candidate\'s resume based on a given job description.\n\n    **Example Prompt Format:**  \n    "Analyze the following job description and resume. Extract key job requirements, candidate qualifications, \n    compare them, and provide a structured match score along with hiring recommendations."\n\n    Now, generate a high-quality prompt for resume screening and evaluation for: \n    **Senior Data Scientist - AI & Machine Learning**\n', 'stream': False, 'options': {'temperature': 0.5, 'num_ctx': 1024, 'num_predict': 300}}
#
# ✅ **Test Completed: Meta-Prompting - AI Generates Resume Evaluation Prompt | Model: mistral**
# 🕒 **Time Taken:** 36.067 seconds
# 📌 **Response:**  "Evaluate the provided Senior Data Scientist - AI & Machine Learning job description and candidate's resume. Identify crucial job requirements such as technical skills (e.g., programming languages, machine learning frameworks), academic background, years of experience, specific projects or achievements relevant to AI/ML, and any other essential qualifications. Compare these requirements with the candidate's qualifications and experiences. Provide a structured comparison in the form of a match score for each requirement (e.g., 100% match, 80%, 50%) and offer hiring recommendations based on the overall match score and any other relevant factors."
#
#
# 🚀 Running test: Meta-Prompting - AI Generates Resume Evaluation Prompt | Model: mistral | Temp: 1.0 | Context: 1024 | Predict: 300...
#
# {'model': 'mistral', 'prompt': '\n    You are an AI prompt engineer. Before performing resume screening, generate the **best possible prompt** \n    for an AI system to analyze and evaluate a candidate\'s resume based on a given job description.\n\n    **Example Prompt Format:**  \n    "Analyze the following job description and resume. Extract key job requirements, candidate qualifications, \n    compare them, and provide a structured match score along with hiring recommendations."\n\n    Now, generate a high-quality prompt for resume screening and evaluation for: \n    **Senior Data Scientist - AI & Machine Learning**\n', 'stream': False, 'options': {'temperature': 1.0, 'num_ctx': 1024, 'num_predict': 300}}
#
# ✅ **Test Completed: Meta-Prompting - AI Generates Resume Evaluation Prompt | Model: mistral**
# 🕒 **Time Taken:** 24.639 seconds
# 📌 **Response:**  "Analyze the provided job description for the role of 'Senior Data Scientist - AI & Machine Learning' and the submitted candidate's resume. Identify essential skills, qualifications, and experiences required for the position as well as the candidate's relevant abilities. Compare these items and calculate a match score based on a scale from 1-5 (1 being poor match, 5 being exceptional match). Provide an explanation of the scoring and any specific areas where the candidate excels or falls short. Additionally, offer potential recommendations for the hiring team, such as additional qualifications that the candidate might need to fulfill the position effectively."
#
#
# 🚀 Running test: Meta-Prompting - AI Generates Resume Evaluation Prompt | Model: llama3 | Temp: 0.5 | Context: 1024 | Predict: 300...
#
# {'model': 'llama3', 'prompt': '\n    You are an AI prompt engineer. Before performing resume screening, generate the **best possible prompt** \n    for an AI system to analyze and evaluate a candidate\'s resume based on a given job description.\n\n    **Example Prompt Format:**  \n    "Analyze the following job description and resume. Extract key job requirements, candidate qualifications, \n    compare them, and provide a structured match score along with hiring recommendations."\n\n    Now, generate a high-quality prompt for resume screening and evaluation for: \n    **Senior Data Scientist - AI & Machine Learning**\n', 'stream': False, 'options': {'temperature': 0.5, 'num_ctx': 1024, 'num_predict': 300}}
#
# ✅ **Test Completed: Meta-Prompting - AI Generates Resume Evaluation Prompt | Model: llama3**
# 🕒 **Time Taken:** 75.307 seconds
# 📌 **Response:** Here is a high-quality prompt for resume screening and evaluation for the Senior Data Scientist - AI & Machine Learning position:
#
# "Analyze the following job description and resume. Identify and extract key requirements from the job posting, including:
#
# * Technical skills in AI/ML frameworks (e.g., TensorFlow, PyTorch, Scikit-Learn)
# * Programming languages proficiency (e.g., Python, R, Julia)
# * Data management and manipulation experience with large datasets
# * Strong understanding of statistical modeling and data visualization techniques
# * Ability to design and implement experiments to test hypotheses
# * Familiarity with cloud-based platforms (e.g., AWS, GCP, Azure) for data processing and deployment
#
# Using these requirements, evaluate the candidate's resume against the job description. Extract relevant qualifications from the resume, including:
#
# * Relevant work experience in AI/ML development and application
# * Education and certifications in data science or related fields
# * Key skills and tools proficiency (e.g., deep learning libraries, data visualization software)
# * Achievements and contributions to projects or teams
#
# Compare the extracted job requirements with the candidate's qualifications. Provide a structured match score out of 10 points, considering factors such as:
#
# * Relevance of technical skills to AI/ML development
# * Depth of experience in data management and manipulation
# * Strength of statistical modeling and data visualization expertise
# * Ability to design and implement experiments
#
# Based on this evaluation, provide hiring recommendations, including:
#
# * A list of top candidate strengths and areas
#
#
# 🚀 Running test: Meta-Prompting - AI Generates Resume Evaluation Prompt | Model: llama3 | Temp: 1.0 | Context: 1024 | Predict: 300...
#
# {'model': 'llama3', 'prompt': '\n    You are an AI prompt engineer. Before performing resume screening, generate the **best possible prompt** \n    for an AI system to analyze and evaluate a candidate\'s resume based on a given job description.\n\n    **Example Prompt Format:**  \n    "Analyze the following job description and resume. Extract key job requirements, candidate qualifications, \n    compare them, and provide a structured match score along with hiring recommendations."\n\n    Now, generate a high-quality prompt for resume screening and evaluation for: \n    **Senior Data Scientist - AI & Machine Learning**\n', 'stream': False, 'options': {'temperature': 1.0, 'num_ctx': 1024, 'num_predict': 300}}
#
# ✅ **Test Completed: Meta-Prompting - AI Generates Resume Evaluation Prompt | Model: llama3**
# 🕒 **Time Taken:** 60.558 seconds
# 📌 **Response:** Here's the best possible prompt for an AI system to analyze and evaluate a candidate's resume based on a Senior Data Scientist - AI & Machine Learning job description:
#
# **Resume Screening Prompt:**
#
# "Analyze the following job description and resume of a Senior Data Scientist - AI & Machine Learning candidate. Extract the key job requirements, including:
#
# * Technical skills in programming languages (e.g., Python, R), data science frameworks (e.g., TensorFlow, PyTorch), and tools (e.g., Jupyter Notebook, Tableau)
# * Experience with machine learning algorithms (e.g., supervised/unsupervised learning, clustering, decision trees) and deep learning techniques
# * Familiarity with large-scale data processing, data pipelines, and data governance practices
# * Ability to work with diverse data sources (e.g., relational databases, NoSQL databases, cloud storage)
# * Strong analytical and problem-solving skills, with expertise in data visualization and storytelling
#
# Compare the extracted job requirements with the candidate's resume, highlighting:
#
# * Relevant education and certifications (e.g., Ph.D. in Data Science, Certified Data Scientist)
# * Quantifiable work experience in AI/ML development, deployment, and maintenance
# * Leadership or collaboration experience in data science teams or projects
# * Publications or presentations in top-tier conferences or journals on AI/ML topics
#
# Provide a structured match score (0-10) based on the candidate's qualifications relative to the job requirements. Additionally, offer hiring recommendations, including:
#
# * Potential for
#
#
# 🚀 Running test: Meta-Prompting - AI Generates Resume Evaluation Prompt | Model: phi3 | Temp: 0.5 | Context: 1024 | Predict: 300...
#
# {'model': 'phi3', 'prompt': '\n    You are an AI prompt engineer. Before performing resume screening, generate the **best possible prompt** \n    for an AI system to analyze and evaluate a candidate\'s resume based on a given job description.\n\n    **Example Prompt Format:**  \n    "Analyze the following job description and resume. Extract key job requirements, candidate qualifications, \n    compare them, and provide a structured match score along with hiring recommendations."\n\n    Now, generate a high-quality prompt for resume screening and evaluation for: \n    **Senior Data Scientist - AI & Machine Learning**\n', 'stream': False, 'options': {'temperature': 0.5, 'num_ctx': 1024, 'num_predict': 300}}
#
# ✅ **Test Completed: Meta-Prompting - AI Generates Resume Evaluation Prompt | Model: phi3**
# 🕒 **Time Taken:** 33.843 seconds
# 📌 **Response:** Analyze the job description for Senior Data Scientist position specializing in AI & Machine Learning. Review candidate's resume with a focus on their educational background, work experience relevant to data science and machine learning fields, technical skills (e.g., programming languages used such as Python or R), publications/research contributions if any, proficiency in statistical analysis tools like SPSS or SAS, knowledge of AI frameworks and libraries, understanding of ML algorithms, project management capabilities demonstrated through portfolio projects, communication skills evidenced by presentations or reports written. Compare these qualifications against the job description's requirements for experience level (senior), industry expertise in data science/AI & machine learning, technical abilities as specified within the role’s responsibilities and necessary certifications if mentioned. Provide a structured match score ranging from 0 to 10 based on how closely the candidate matches each criterion of the job description along with personalized hiring recommendations highlighting areas where further experience or skills could be beneficial for this role, considering both quantitative and qualitative aspects extracted from their resume.
#
#
# 🚀 Running test: Meta-Prompting - AI Generates Resume Evaluation Prompt | Model: phi3 | Temp: 1.0 | Context: 1024 | Predict: 300...
#
# {'model': 'phi3', 'prompt': '\n    You are an AI prompt engineer. Before performing resume screening, generate the **best possible prompt** \n    for an AI system to analyze and evaluate a candidate\'s resume based on a given job description.\n\n    **Example Prompt Format:**  \n    "Analyze the following job description and resume. Extract key job requirements, candidate qualifications, \n    compare them, and provide a structured match score along with hiring recommendations."\n\n    Now, generate a high-quality prompt for resume screening and evaluation for: \n    **Senior Data Scientist - AI & Machine Learning**\n', 'stream': False, 'options': {'temperature': 1.0, 'num_ctx': 1024, 'num_predict': 300}}
#
# ✅ **Test Completed: Meta-Prompting - AI Generates Resume Evaluation Prompt | Model: phi3**
# 🕒 **Time Taken:** 26.493 seconds
# 📌 **Response:** "Analyze the job description of 'Senior Data Scientist – Artificial Intelligence & Machine Learning' focusing on required skills, experience level needed, and specific industry relevance. Scrutinize a candidate’s resume applying to this position for alignment with these requirements including educational background, technical proficiencies in AI/ML tools like Python, R, TensorFlow, PyTorch; machine learning algorithms expertise such as SVM, Neural Networks and Deep Learning; data mining skills along with statistical analysis capabilities. Evaluate the resume content for any certifications or specializations relevant to 'Senior Data Scientist' roles (e.g., Certified Analytics Professional), leadership experience indicative of seniority levels like mentorship, project management in AI/ML environments; and notable professional affiliations with reputable tech organizations such as KDD/ICDE conferences or Google DeepMind alumni network involvement if any. Provide a structured match score based on each qualification's weight against the job description parameters, culminating in personalized hiring recommendations for forward-step actions with top candidate(s) considering company values of innovation and teamwork fit."
#
#
# 🚀 Running test: Multi-Step Iterative Resume Evaluation | Model: mistral | Temp: 0.5 | Context: 1024 | Predict: 300...
#
# {'model': 'mistral', 'prompt': '\n    You are an AI hiring assistant performing **iterative resume screening**. \n\n    **Step 1: Initial Candidate Evaluation**\n    - Extract key job requirements.\n    - Extract candidate qualifications.\n    - Identify skill matches and gaps.\n\n    **Step 2: Self-Reflection & Gap Analysis**\n    - Identify missing or vague areas.\n    - Determine if further clarifications are needed (e.g., missing certifications, unclear experience level).\n\n    **Step 3: Resume Refinement & Decision Making**\n    - Improve initial analysis by filling gaps.\n    - Optimize scoring for accuracy and fairness.\n    - Provide a structured match score (0-100%) and hiring recommendation.\n\n    **Job Description:** \n                We are hiring a Senior Data Scientist with expertise in AI, Machine Learning, and Python. \n                The candidate must have at least 5 years of experience and strong statistical modeling skills. \n                Experience with cloud platforms (AWS, GCP) and NLP is a plus.\n            \n    **Candidate Resume:** \n                John Doe is a Data Scientist with 6 years of experience. Skilled in Python, Machine Learning, and AI. \n                He has worked on predictive modeling, NLP applications, and statistical analysis. \n                Familiar with AWS, but lacks experience with GCP.\n            \n', 'stream': False, 'options': {'temperature': 0.5, 'num_ctx': 1024, 'num_predict': 300}}
#
# ✅ **Test Completed: Multi-Step Iterative Resume Evaluation | Model: mistral**
# 🕒 **Time Taken:** 75.233 seconds
# 📌 **Response:**  **Step 1: Initial Candidate Evaluation**
#    - Job Requirements: Senior Data Scientist, AI, Machine Learning, Python (minimum 5 years of experience), Strong Statistical Modeling Skills, Experience with cloud platforms (AWS, GCP), NLP is a plus.
#    - Candidate Qualifications: Data Scientist, 6 years of experience, Skilled in Python, Machine Learning, AI, Predictive Modeling, NLP applications, Statistical Analysis, Familiar with AWS but lacks experience with GCP.
#    - Skill Matches: Python (100%), Machine Learning (100%), AI (100%), Predictive Modeling (100%), Statistical Analysis (100%), NLP applications (80%, as it's a plus but not explicitly required).
#    - Skill Gaps: Experience with cloud platforms (AWS, GCP) (90%, as he only has experience with AWS and lacks GCP experience which is a requirement for the Senior role).
#
#    **Step 2: Self-Reflection & Gap Analysis**
#    - Missing or vague areas: Experience with GCP.
#    - Further clarifications needed: None at this stage, as the information provided in the resume seems clear and consistent.
#
#    **Step 3: Resume Refinement &
#
#
# 🚀 Running test: Multi-Step Iterative Resume Evaluation | Model: mistral | Temp: 1.0 | Context: 1024 | Predict: 300...
#
# {'model': 'mistral', 'prompt': '\n    You are an AI hiring assistant performing **iterative resume screening**. \n\n    **Step 1: Initial Candidate Evaluation**\n    - Extract key job requirements.\n    - Extract candidate qualifications.\n    - Identify skill matches and gaps.\n\n    **Step 2: Self-Reflection & Gap Analysis**\n    - Identify missing or vague areas.\n    - Determine if further clarifications are needed (e.g., missing certifications, unclear experience level).\n\n    **Step 3: Resume Refinement & Decision Making**\n    - Improve initial analysis by filling gaps.\n    - Optimize scoring for accuracy and fairness.\n    - Provide a structured match score (0-100%) and hiring recommendation.\n\n    **Job Description:** \n                We are hiring a Senior Data Scientist with expertise in AI, Machine Learning, and Python. \n                The candidate must have at least 5 years of experience and strong statistical modeling skills. \n                Experience with cloud platforms (AWS, GCP) and NLP is a plus.\n            \n    **Candidate Resume:** \n                John Doe is a Data Scientist with 6 years of experience. Skilled in Python, Machine Learning, and AI. \n                He has worked on predictive modeling, NLP applications, and statistical analysis. \n                Familiar with AWS, but lacks experience with GCP.\n            \n', 'stream': False, 'options': {'temperature': 1.0, 'num_ctx': 1024, 'num_predict': 300}}
#
# ✅ **Test Completed: Multi-Step Iterative Resume Evaluation | Model: mistral**
# 🕒 **Time Taken:** 53.769 seconds
# 📌 **Response:**  Based on the initial evaluation:
#
#    **Step 1: Initial Candidate Evaluation**
#    - Job Requirements: Senior Data Scientist, AI, Machine Learning, Python, at least 5 years of experience, strong statistical modeling skills, experience with cloud platforms (AWS, GCP), NLP is a plus.
#    - Candidate Qualifications: Data Scientist with 6 years of experience, skilled in Python, Machine Learning, and AI, experience with predictive modeling, NLP applications, and statistical analysis, familiar with AWS but lacks experience with GCP.
#    - Skill Matches: Python, Machine Learning, AI, Predictive Modeling, Statistical Analysis, NLP (Partial Match).
#    - Skill Gaps: Lack of 1 year of experience according to job requirements, and experience with GCP.
#
#    **Step 2: Self-Reflection & Gap Analysis**
#    - Missing Area: 1 year of experience according to job requirements, and lacks experience with GCP.
#    - Further Clarification Needed: None for this candidate as all necessary information is provided.
#
#    **Step 3: Resume Refinement & Decision Making**
#    - Improved Analysis: John Doe has relevant skills (Python, Machine Learning, AI) and experience (predictive modeling, NLP applications, statistical analysis) for the role. However,
#
#
# 🚀 Running test: Multi-Step Iterative Resume Evaluation | Model: llama3 | Temp: 0.5 | Context: 1024 | Predict: 300...
#
# {'model': 'llama3', 'prompt': '\n    You are an AI hiring assistant performing **iterative resume screening**. \n\n    **Step 1: Initial Candidate Evaluation**\n    - Extract key job requirements.\n    - Extract candidate qualifications.\n    - Identify skill matches and gaps.\n\n    **Step 2: Self-Reflection & Gap Analysis**\n    - Identify missing or vague areas.\n    - Determine if further clarifications are needed (e.g., missing certifications, unclear experience level).\n\n    **Step 3: Resume Refinement & Decision Making**\n    - Improve initial analysis by filling gaps.\n    - Optimize scoring for accuracy and fairness.\n    - Provide a structured match score (0-100%) and hiring recommendation.\n\n    **Job Description:** \n                We are hiring a Senior Data Scientist with expertise in AI, Machine Learning, and Python. \n                The candidate must have at least 5 years of experience and strong statistical modeling skills. \n                Experience with cloud platforms (AWS, GCP) and NLP is a plus.\n            \n    **Candidate Resume:** \n                John Doe is a Data Scientist with 6 years of experience. Skilled in Python, Machine Learning, and AI. \n                He has worked on predictive modeling, NLP applications, and statistical analysis. \n                Familiar with AWS, but lacks experience with GCP.\n            \n', 'stream': False, 'options': {'temperature': 0.5, 'num_ctx': 1024, 'num_predict': 300}}
#
# ✅ **Test Completed: Multi-Step Iterative Resume Evaluation | Model: llama3**
# 🕒 **Time Taken:** 70.086 seconds
# 📌 **Response:** **Initial Candidate Evaluation**
#
# **Key Job Requirements:**
#
# 1. Expertise in AI, Machine Learning, and Python
# 2. At least 5 years of experience as a Senior Data Scientist
# 3. Strong statistical modeling skills
# 4. Experience with cloud platforms (AWS, GCP)
# 5. NLP expertise is a plus
#
# **Candidate Qualifications:**
#
# 1. 6 years of experience as a Data Scientist (meets experience requirement)
# 2. Skilled in Python, Machine Learning, and AI (matches job requirements)
# 3. Familiar with AWS (partially meets cloud platform requirement)
# 4. Experience with predictive modeling, NLP applications, and statistical analysis (matches job requirements)
#
# **Skill Matches and Gaps:**
#
# * Matches:
# 	+ Python, Machine Learning, AI
# 	+ Predictive modeling, NLP applications, statistical analysis
# * Gaps:
# 	+ Lack of experience with GCP
# 	+ Not explicitly stated as having 5+ years of experience as a Senior Data Scientist (although total experience is 6 years)
#
# **Self-Reflection & Gap Analysis**
#
# The candidate's resume highlights their skills in AI, Machine Learning, and Python, which aligns well with the job requirements. However, there are two areas that require further clarification:
#
# 1. **GCP Experience:** The candidate lacks hands-on experience with GCP, which is a requirement. This may impact their ability to work effectively on cloud-based projects.
# 2. **Experience Level:** Although the
#
#
# 🚀 Running test: Multi-Step Iterative Resume Evaluation | Model: llama3 | Temp: 1.0 | Context: 1024 | Predict: 300...
#
# {'model': 'llama3', 'prompt': '\n    You are an AI hiring assistant performing **iterative resume screening**. \n\n    **Step 1: Initial Candidate Evaluation**\n    - Extract key job requirements.\n    - Extract candidate qualifications.\n    - Identify skill matches and gaps.\n\n    **Step 2: Self-Reflection & Gap Analysis**\n    - Identify missing or vague areas.\n    - Determine if further clarifications are needed (e.g., missing certifications, unclear experience level).\n\n    **Step 3: Resume Refinement & Decision Making**\n    - Improve initial analysis by filling gaps.\n    - Optimize scoring for accuracy and fairness.\n    - Provide a structured match score (0-100%) and hiring recommendation.\n\n    **Job Description:** \n                We are hiring a Senior Data Scientist with expertise in AI, Machine Learning, and Python. \n                The candidate must have at least 5 years of experience and strong statistical modeling skills. \n                Experience with cloud platforms (AWS, GCP) and NLP is a plus.\n            \n    **Candidate Resume:** \n                John Doe is a Data Scientist with 6 years of experience. Skilled in Python, Machine Learning, and AI. \n                He has worked on predictive modeling, NLP applications, and statistical analysis. \n                Familiar with AWS, but lacks experience with GCP.\n            \n', 'stream': False, 'options': {'temperature': 1.0, 'num_ctx': 1024, 'num_predict': 300}}
#
# ✅ **Test Completed: Multi-Step Iterative Resume Evaluation | Model: llama3**
# 🕒 **Time Taken:** 56.322 seconds
# 📌 **Response:** **Initial Candidate Evaluation (Step 1)**
#
# **Key Job Requirements:**
#
# * Senior Data Scientist with expertise in AI, Machine Learning, and Python
# * At least 5 years of experience
# * Strong statistical modeling skills
# * Experience with cloud platforms (AWS, GCP)
# * NLP is a plus
#
# **Candidate Qualifications:**
#
# * John Doe is a Data Scientist with 6 years of experience
# * Skilled in Python, Machine Learning, and AI
# * Has worked on predictive modeling, NLP applications, and statistical analysis
# * Familiar with AWS, but lacks experience with GCP
#
# **Skill Matches and Gaps:**
#
# * Matched skills:
# 	+ AI and Machine Learning expertise
# 	+ Python proficiency
# 	+ Predictive modeling, NLP, and statistical analysis experience
# * Skill gaps:
# 	+ Insufficient cloud platform experience (AWS only, lacking GCP)
# 	+ May not meet the minimum 5-year experience requirement
#
# **Self-Reflection & Gap Analysis (Step 2)**
#
# * Missing or vague areas: None identified.
# * Determining if further clarifications are needed:
# 	+ Request additional information on John's specific experience with AWS and potential familiarity with other cloud platforms.
#
# **Resume Refinement & Decision Making (Step 3)**
#
# Based on the initial evaluation, John Doe's resume shows a good match for some of the job requirements. However, the lack of GCP experience and potentially insufficient overall experience may raise concerns.
#
# To
#
#
# 🚀 Running test: Multi-Step Iterative Resume Evaluation | Model: phi3 | Temp: 0.5 | Context: 1024 | Predict: 300...
#
# {'model': 'phi3', 'prompt': '\n    You are an AI hiring assistant performing **iterative resume screening**. \n\n    **Step 1: Initial Candidate Evaluation**\n    - Extract key job requirements.\n    - Extract candidate qualifications.\n    - Identify skill matches and gaps.\n\n    **Step 2: Self-Reflection & Gap Analysis**\n    - Identify missing or vague areas.\n    - Determine if further clarifications are needed (e.g., missing certifications, unclear experience level).\n\n    **Step 3: Resume Refinement & Decision Making**\n    - Improve initial analysis by filling gaps.\n    - Optimize scoring for accuracy and fairness.\n    - Provide a structured match score (0-100%) and hiring recommendation.\n\n    **Job Description:** \n                We are hiring a Senior Data Scientist with expertise in AI, Machine Learning, and Python. \n                The candidate must have at least 5 years of experience and strong statistical modeling skills. \n                Experience with cloud platforms (AWS, GCP) and NLP is a plus.\n            \n    **Candidate Resume:** \n                John Doe is a Data Scientist with 6 years of experience. Skilled in Python, Machine Learning, and AI. \n                He has worked on predictive modeling, NLP applications, and statistical analysis. \n                Familiar with AWS, but lacks experience with GCP.\n            \n', 'stream': False, 'options': {'temperature': 0.5, 'num_ctx': 1024, 'num_predict': 300}}
#
# ✅ **Test Completed: Multi-Step Iterative Resume Evaluation | Model: phi3**
# 🕒 **Time Taken:** 38.447 seconds
# 📌 **Response:** **Step 1: Initial Candidate Evaluation**
# - Key Job Requirements: Senior Data Scientist (5+ years), AI/ML expertise, Python skills, statistical modeling, cloud platform familiarity (AWS and possibly GCP).
# - Candidate Qualifications: John Doe has 6 years of experience as a Data Scientist with relevant skill sets. He is skilled in Python, Machine Learning, Artificial Intelligence, predictive modeling, NLP applications, and statistical analysis which aligns well with the job description's requirements for AI/ML expertise and Python skills.
# - Skill Matches: John Doe meets most of the skill matches required by the job like experience in data science field (6 years), ML & AI knowledge, proficiency in python programming language which is a must have as per the requirement stated above. He also has some NLP application and predictive modeling skills that are relevant to the role; however, he lacks GCP familiarity while AWS experience aligns with job requirements.
# - Skill gaps: Lack of Google Cloud Platform (GCP) expertise is a gap in John Doe's qualifications as per the given resume and job description which requires some knowledge or skills related to cloud platforms along with proficiency on at least one platform between AWS & GCP.
#
# **Step 2: Self-
#
#
# 🚀 Running test: Multi-Step Iterative Resume Evaluation | Model: phi3 | Temp: 1.0 | Context: 1024 | Predict: 300...
#
# {'model': 'phi3', 'prompt': '\n    You are an AI hiring assistant performing **iterative resume screening**. \n\n    **Step 1: Initial Candidate Evaluation**\n    - Extract key job requirements.\n    - Extract candidate qualifications.\n    - Identify skill matches and gaps.\n\n    **Step 2: Self-Reflection & Gap Analysis**\n    - Identify missing or vague areas.\n    - Determine if further clarifications are needed (e.g., missing certifications, unclear experience level).\n\n    **Step 3: Resume Refinement & Decision Making**\n    - Improve initial analysis by filling gaps.\n    - Optimize scoring for accuracy and fairness.\n    - Provide a structured match score (0-100%) and hiring recommendation.\n\n    **Job Description:** \n                We are hiring a Senior Data Scientist with expertise in AI, Machine Learning, and Python. \n                The candidate must have at least 5 years of experience and strong statistical modeling skills. \n                Experience with cloud platforms (AWS, GCP) and NLP is a plus.\n            \n    **Candidate Resume:** \n                John Doe is a Data Scientist with 6 years of experience. Skilled in Python, Machine Learning, and AI. \n                He has worked on predictive modeling, NLP applications, and statistical analysis. \n                Familiar with AWS, but lacks experience with GCP.\n            \n', 'stream': False, 'options': {'temperature': 1.0, 'num_ctx': 1024, 'num_predict': 300}}
#
# ✅ **Test Completed: Multi-Step Iterative Resume Evaluation | Model: phi3**
# 🕒 **Time Taken:** 27.687 seconds
# 📌 **Response:**
# **Step 1: Initial Candidate Evaluation**
# - Job Requirements Extracted (Key Points): Senior Data Scientist role needed; AI expertise essential along with ML and Python skills required; minimum of 5 years experience expected, strong statistical modeling abilities necessary. Experience in cloud platforms like AWS or GCP is desired but not mandatory for the position.
# - Candidate Qualifications Extracted: John Doe possesses Data Science qualification (not detailed), expertise with Python and machine learning alongside AI knowledge; 6 years of experience aligns with job requirement, predictive modeling in action points to strong statistical skills likely needed. Experience related to NLP applications mentioned as well. Familiarity is stated with AWS platform only but not GCP which indicates a possible area for additional skill growth.
# - Skill Matches: John Doe exhibits relevant qualifications and experience directly aligns with job description's prerequisites - AI, ML skills, Python proficiency, predictive modeling (implying statistical models knowledge), NLP application involvement; AWS familiarity fulfills the cloud platform requirement partially.
# - Skill Gaps: Lack of explicit experience in senior roles and any mention of certifications or specialized projects to demonstrate AI expertise is a notable deficit, along with unstated proficiency level (novice/
# [{'Test Case': 'Meta-Prompting - AI Generates Resume Evaluation Prompt',
#   'Model': 'mistral',
#   'Temperature': 0.5,
#   'Context Size': 1024,
#   'Num Predict': 300,
#   'Time Taken (s)': 36.067,
#   'Response Sample': ' "Evaluate the provided Senior Data Scientist - AI & Machine Learning job description and candidate\'s resume. Identify crucial job requirements such as technical skills (e.g., programming languages, machine learning frameworks), academic background, years of experience, specific projects or achievements relevant to AI/ML, and any other essential qualifications. Compare these requirements with the candidate\'s qualifications and experiences. Provide a structured comparison in the form of a match score for each requirement (e.g., 100% match, 80%, 50%) and offer hiring recommendations based on the overall match score and any other relevant factors."'},
#  {'Test Case': 'Meta-Prompting - AI Generates Resume Evaluation Prompt',
#   'Model': 'mistral',
#   'Temperature': 1.0,
#   'Context Size': 1024,
#   'Num Predict': 300,
#   'Time Taken (s)': 24.639,
#   'Response Sample': ' "Analyze the provided job description for the role of \'Senior Data Scientist - AI & Machine Learning\' and the submitted candidate\'s resume. Identify essential skills, qualifications, and experiences required for the position as well as the candidate\'s relevant abilities. Compare these items and calculate a match score based on a scale from 1-5 (1 being poor match, 5 being exceptional match). Provide an explanation of the scoring and any specific areas where the candidate excels or falls short. Additionally, offer potential recommendations for the hiring team, such as additional qualifications that the candidate might need to fulfill the position effectively."'},
#  {'Test Case': 'Meta-Prompting - AI Generates Resume Evaluation Prompt',
#   'Model': 'llama3',
#   'Temperature': 0.5,
#   'Context Size': 1024,
#   'Num Predict': 300,
#   'Time Taken (s)': 75.307,
#   'Response Sample': 'Here is a high-quality prompt for resume screening and evaluation for the Senior Data Scientist - AI & Machine Learning position:\n\n"Analyze the following job description and resume. Identify and extract key requirements from the job posting, including:\n\n* Technical skills in AI/ML frameworks (e.g., TensorFlow, PyTorch, Scikit-Learn)\n* Programming languages proficiency (e.g., Python, R, Julia)\n* Data management and manipulation experience with large datasets\n* Strong understanding of statistical modeling and data visualization techniques\n* Ability to design and implement experiments to test hypotheses\n* Familiarity with cloud-based platforms (e.g., AWS, GCP, Azure) for data processing and deployment\n\nUsing these requirements, evaluate the candidate\'s resume against the job description. Extract relevant qualifications from the resume, including:\n\n* Relevant work experience in AI/ML development and application\n* Education and certifications in data science or related fields\n* Key skills and tools proficiency (e.g., deep learning libraries, data visualization software)\n* Achievements and contributions to projects or teams\n\nCompare the extracted job requirements with the candidate\'s qualifications. Provide a structured match score out of 10 points, considering factors such as:\n\n* Relevance of technical skills to AI/ML development\n* Depth of experience in data management and manipulation\n* Strength of statistical modeling and data visualization expertise\n* Ability to design and implement experiments\n\nBased on this evaluation, provide hiring recommendations, including:\n\n* A list of top candidate strengths and areas'},
#  {'Test Case': 'Meta-Prompting - AI Generates Resume Evaluation Prompt',
#   'Model': 'llama3',
#   'Temperature': 1.0,
#   'Context Size': 1024,
#   'Num Predict': 300,
#   'Time Taken (s)': 60.558,
#   'Response Sample': 'Here\'s the best possible prompt for an AI system to analyze and evaluate a candidate\'s resume based on a Senior Data Scientist - AI & Machine Learning job description:\n\n**Resume Screening Prompt:**\n\n"Analyze the following job description and resume of a Senior Data Scientist - AI & Machine Learning candidate. Extract the key job requirements, including:\n\n* Technical skills in programming languages (e.g., Python, R), data science frameworks (e.g., TensorFlow, PyTorch), and tools (e.g., Jupyter Notebook, Tableau)\n* Experience with machine learning algorithms (e.g., supervised/unsupervised learning, clustering, decision trees) and deep learning techniques\n* Familiarity with large-scale data processing, data pipelines, and data governance practices\n* Ability to work with diverse data sources (e.g., relational databases, NoSQL databases, cloud storage)\n* Strong analytical and problem-solving skills, with expertise in data visualization and storytelling\n\nCompare the extracted job requirements with the candidate\'s resume, highlighting:\n\n* Relevant education and certifications (e.g., Ph.D. in Data Science, Certified Data Scientist)\n* Quantifiable work experience in AI/ML development, deployment, and maintenance\n* Leadership or collaboration experience in data science teams or projects\n* Publications or presentations in top-tier conferences or journals on AI/ML topics\n\nProvide a structured match score (0-10) based on the candidate\'s qualifications relative to the job requirements. Additionally, offer hiring recommendations, including:\n\n* Potential for'},
#  {'Test Case': 'Meta-Prompting - AI Generates Resume Evaluation Prompt',
#   'Model': 'phi3',
#   'Temperature': 0.5,
#   'Context Size': 1024,
#   'Num Predict': 300,
#   'Time Taken (s)': 33.843,
#   'Response Sample': "Analyze the job description for Senior Data Scientist position specializing in AI & Machine Learning. Review candidate's resume with a focus on their educational background, work experience relevant to data science and machine learning fields, technical skills (e.g., programming languages used such as Python or R), publications/research contributions if any, proficiency in statistical analysis tools like SPSS or SAS, knowledge of AI frameworks and libraries, understanding of ML algorithms, project management capabilities demonstrated through portfolio projects, communication skills evidenced by presentations or reports written. Compare these qualifications against the job description's requirements for experience level (senior), industry expertise in data science/AI & machine learning, technical abilities as specified within the role’s responsibilities and necessary certifications if mentioned. Provide a structured match score ranging from 0 to 10 based on how closely the candidate matches each criterion of the job description along with personalized hiring recommendations highlighting areas where further experience or skills could be beneficial for this role, considering both quantitative and qualitative aspects extracted from their resume."},
#  {'Test Case': 'Meta-Prompting - AI Generates Resume Evaluation Prompt',
#   'Model': 'phi3',
#   'Temperature': 1.0,
#   'Context Size': 1024,
#   'Num Predict': 300,
#   'Time Taken (s)': 26.493,
#   'Response Sample': '"Analyze the job description of \'Senior Data Scientist – Artificial Intelligence & Machine Learning\' focusing on required skills, experience level needed, and specific industry relevance. Scrutinize a candidate’s resume applying to this position for alignment with these requirements including educational background, technical proficiencies in AI/ML tools like Python, R, TensorFlow, PyTorch; machine learning algorithms expertise such as SVM, Neural Networks and Deep Learning; data mining skills along with statistical analysis capabilities. Evaluate the resume content for any certifications or specializations relevant to \'Senior Data Scientist\' roles (e.g., Certified Analytics Professional), leadership experience indicative of seniority levels like mentorship, project management in AI/ML environments; and notable professional affiliations with reputable tech organizations such as KDD/ICDE conferences or Google DeepMind alumni network involvement if any. Provide a structured match score based on each qualification\'s weight against the job description parameters, culminating in personalized hiring recommendations for forward-step actions with top candidate(s) considering company values of innovation and teamwork fit."'},
#  {'Test Case': 'Multi-Step Iterative Resume Evaluation',
#   'Model': 'mistral',
#   'Temperature': 0.5,
#   'Context Size': 1024,
#   'Num Predict': 300,
#   'Time Taken (s)': 75.233,
#   'Response Sample': " **Step 1: Initial Candidate Evaluation**\n   - Job Requirements: Senior Data Scientist, AI, Machine Learning, Python (minimum 5 years of experience), Strong Statistical Modeling Skills, Experience with cloud platforms (AWS, GCP), NLP is a plus.\n   - Candidate Qualifications: Data Scientist, 6 years of experience, Skilled in Python, Machine Learning, AI, Predictive Modeling, NLP applications, Statistical Analysis, Familiar with AWS but lacks experience with GCP.\n   - Skill Matches: Python (100%), Machine Learning (100%), AI (100%), Predictive Modeling (100%), Statistical Analysis (100%), NLP applications (80%, as it's a plus but not explicitly required).\n   - Skill Gaps: Experience with cloud platforms (AWS, GCP) (90%, as he only has experience with AWS and lacks GCP experience which is a requirement for the Senior role).\n\n   **Step 2: Self-Reflection & Gap Analysis**\n   - Missing or vague areas: Experience with GCP.\n   - Further clarifications needed: None at this stage, as the information provided in the resume seems clear and consistent.\n\n   **Step 3: Resume Refinement &"},
#  {'Test Case': 'Multi-Step Iterative Resume Evaluation',
#   'Model': 'mistral',
#   'Temperature': 1.0,
#   'Context Size': 1024,
#   'Num Predict': 300,
#   'Time Taken (s)': 53.769,
#   'Response Sample': ' Based on the initial evaluation:\n\n   **Step 1: Initial Candidate Evaluation**\n   - Job Requirements: Senior Data Scientist, AI, Machine Learning, Python, at least 5 years of experience, strong statistical modeling skills, experience with cloud platforms (AWS, GCP), NLP is a plus.\n   - Candidate Qualifications: Data Scientist with 6 years of experience, skilled in Python, Machine Learning, and AI, experience with predictive modeling, NLP applications, and statistical analysis, familiar with AWS but lacks experience with GCP.\n   - Skill Matches: Python, Machine Learning, AI, Predictive Modeling, Statistical Analysis, NLP (Partial Match).\n   - Skill Gaps: Lack of 1 year of experience according to job requirements, and experience with GCP.\n\n   **Step 2: Self-Reflection & Gap Analysis**\n   - Missing Area: 1 year of experience according to job requirements, and lacks experience with GCP.\n   - Further Clarification Needed: None for this candidate as all necessary information is provided.\n\n   **Step 3: Resume Refinement & Decision Making**\n   - Improved Analysis: John Doe has relevant skills (Python, Machine Learning, AI) and experience (predictive modeling, NLP applications, statistical analysis) for the role. However,'},
#  {'Test Case': 'Multi-Step Iterative Resume Evaluation',
#   'Model': 'llama3',
#   'Temperature': 0.5,
#   'Context Size': 1024,
#   'Num Predict': 300,
#   'Time Taken (s)': 70.086,
#   'Response Sample': "**Initial Candidate Evaluation**\n\n**Key Job Requirements:**\n\n1. Expertise in AI, Machine Learning, and Python\n2. At least 5 years of experience as a Senior Data Scientist\n3. Strong statistical modeling skills\n4. Experience with cloud platforms (AWS, GCP)\n5. NLP expertise is a plus\n\n**Candidate Qualifications:**\n\n1. 6 years of experience as a Data Scientist (meets experience requirement)\n2. Skilled in Python, Machine Learning, and AI (matches job requirements)\n3. Familiar with AWS (partially meets cloud platform requirement)\n4. Experience with predictive modeling, NLP applications, and statistical analysis (matches job requirements)\n\n**Skill Matches and Gaps:**\n\n* Matches:\n\t+ Python, Machine Learning, AI\n\t+ Predictive modeling, NLP applications, statistical analysis\n* Gaps:\n\t+ Lack of experience with GCP\n\t+ Not explicitly stated as having 5+ years of experience as a Senior Data Scientist (although total experience is 6 years)\n\n**Self-Reflection & Gap Analysis**\n\nThe candidate's resume highlights their skills in AI, Machine Learning, and Python, which aligns well with the job requirements. However, there are two areas that require further clarification:\n\n1. **GCP Experience:** The candidate lacks hands-on experience with GCP, which is a requirement. This may impact their ability to work effectively on cloud-based projects.\n2. **Experience Level:** Although the"},
#  {'Test Case': 'Multi-Step Iterative Resume Evaluation',
#   'Model': 'llama3',
#   'Temperature': 1.0,
#   'Context Size': 1024,
#   'Num Predict': 300,
#   'Time Taken (s)': 56.322,
#   'Response Sample': "**Initial Candidate Evaluation (Step 1)**\n\n**Key Job Requirements:**\n\n* Senior Data Scientist with expertise in AI, Machine Learning, and Python\n* At least 5 years of experience\n* Strong statistical modeling skills\n* Experience with cloud platforms (AWS, GCP)\n* NLP is a plus\n\n**Candidate Qualifications:**\n\n* John Doe is a Data Scientist with 6 years of experience\n* Skilled in Python, Machine Learning, and AI\n* Has worked on predictive modeling, NLP applications, and statistical analysis\n* Familiar with AWS, but lacks experience with GCP\n\n**Skill Matches and Gaps:**\n\n* Matched skills:\n\t+ AI and Machine Learning expertise\n\t+ Python proficiency\n\t+ Predictive modeling, NLP, and statistical analysis experience\n* Skill gaps:\n\t+ Insufficient cloud platform experience (AWS only, lacking GCP)\n\t+ May not meet the minimum 5-year experience requirement\n\n**Self-Reflection & Gap Analysis (Step 2)**\n\n* Missing or vague areas: None identified.\n* Determining if further clarifications are needed:\n\t+ Request additional information on John's specific experience with AWS and potential familiarity with other cloud platforms.\n\n**Resume Refinement & Decision Making (Step 3)**\n\nBased on the initial evaluation, John Doe's resume shows a good match for some of the job requirements. However, the lack of GCP experience and potentially insufficient overall experience may raise concerns.\n\nTo"},
#  {'Test Case': 'Multi-Step Iterative Resume Evaluation',
#   'Model': 'phi3',
#   'Temperature': 0.5,
#   'Context Size': 1024,
#   'Num Predict': 300,
#   'Time Taken (s)': 38.447,
#   'Response Sample': "**Step 1: Initial Candidate Evaluation**\n- Key Job Requirements: Senior Data Scientist (5+ years), AI/ML expertise, Python skills, statistical modeling, cloud platform familiarity (AWS and possibly GCP).\n- Candidate Qualifications: John Doe has 6 years of experience as a Data Scientist with relevant skill sets. He is skilled in Python, Machine Learning, Artificial Intelligence, predictive modeling, NLP applications, and statistical analysis which aligns well with the job description's requirements for AI/ML expertise and Python skills.\n- Skill Matches: John Doe meets most of the skill matches required by the job like experience in data science field (6 years), ML & AI knowledge, proficiency in python programming language which is a must have as per the requirement stated above. He also has some NLP application and predictive modeling skills that are relevant to the role; however, he lacks GCP familiarity while AWS experience aligns with job requirements.\n- Skill gaps: Lack of Google Cloud Platform (GCP) expertise is a gap in John Doe's qualifications as per the given resume and job description which requires some knowledge or skills related to cloud platforms along with proficiency on at least one platform between AWS & GCP.\n\n**Step 2: Self-"},
#  {'Test Case': 'Multi-Step Iterative Resume Evaluation',
#   'Model': 'phi3',
#   'Temperature': 1.0,
#   'Context Size': 1024,
#   'Num Predict': 300,
#   'Time Taken (s)': 27.687,
#   'Response Sample': "\n**Step 1: Initial Candidate Evaluation**\n- Job Requirements Extracted (Key Points): Senior Data Scientist role needed; AI expertise essential along with ML and Python skills required; minimum of 5 years experience expected, strong statistical modeling abilities necessary. Experience in cloud platforms like AWS or GCP is desired but not mandatory for the position.\n- Candidate Qualifications Extracted: John Doe possesses Data Science qualification (not detailed), expertise with Python and machine learning alongside AI knowledge; 6 years of experience aligns with job requirement, predictive modeling in action points to strong statistical skills likely needed. Experience related to NLP applications mentioned as well. Familiarity is stated with AWS platform only but not GCP which indicates a possible area for additional skill growth.\n- Skill Matches: John Doe exhibits relevant qualifications and experience directly aligns with job description's prerequisites - AI, ML skills, Python proficiency, predictive modeling (implying statistical models knowledge), NLP application involvement; AWS familiarity fulfills the cloud platform requirement partially.\n- Skill Gaps: Lack of explicit experience in senior roles and any mention of certifications or specialized projects to demonstrate AI expertise is a notable deficit, along with unstated proficiency level (novice/"}]
